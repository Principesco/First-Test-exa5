# %%
from kanren import run,eq,membero,var,lall
x=var()

from kanren import Relation, facts
padre=Relation()
madre=Relation()
abuelo=Relation()
abuela=Relation()
primo=Relation()
prima=Relation()
tio=Relation()
tia=Relation()
hijo=Relation()
facts(padre,
        ("Valentin","Roberto"),
        ("Valentin","Natalio"),
        ("Valentin","Marcelo"),
        ("Valentin","Julio"), 
        ("Rufino","Valentin"))
facts(madre,
        ("Eliza","Roberto"),
        ("Eliza","Natalio"),
        ("Eliza","Marcelo"),
        ("Eliza","Julio"),
        ("Justina","Eliza"))
facts(abuelo,
         ("Rufino","Roberto"),
         ("Rufino","Marcelo"),
         ("Rufino","Natalio"),
         ("Rufino","Julio"))
facts(abuela,
         ("Justina","Roberto"),
         ("Justina","Marcelo"),
         ("Justina","Natalio"),
         ("Justina","Julio"))
facts(tio,
         ("Juan","Marcelo"),
         ("Juan","Roberto"),
         ("Juan","Natalio"),
         ("Juan","Julio"),
     ("Nataniel","Natalio"),
     ("Nataniel","Marcelo"),
     ("Nataniel","Roberto"),
     ("Nataniel","Julio"),)
facts(tia,
         ("Benedicta","Marcelo"),
         ("Benedicta","Roberto"),
         ("Benedicta","Natalio"),
         ("Benedicta","Julio"))
facts(primo,
         ("Mariano","Marcelo"),
         ("Mariano","Roberto"),
         ("Mariano","Natalio"),
         ("Mariano","Julio"))
facts(prima,
         ("Noemi","Roberto"),
         ("Noemi","Marcelo"),
         ("Noemi","Natalio"),
         ("Noemi","Julio"))
facts(hijo,
         ("Roberto","Valentin"),
         ("Marcelo","Valentin"),
         ("Natalio","Valentin"),
         ("Julio","Valentin"),
     ("Roberto","Eliza"),
     ("Marcelo","Eliza"),
     ("Julio","Eliza"),
     ("Natalio","Eliza"))


print(run(1,x,padre(x,"Roberto")))
print(run(1,x,padre(x,"Natalio")))
print(run(4,x,madre("Eliza",x)))
print(run(4,x,madre(x,"Marcelo")))
print(run(2,x,hijo("Roberto",x)))
